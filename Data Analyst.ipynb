# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import random

# %%
data = pd.read_csv("Database.csv")

# %%
data.head(5)
# Out:
#    Sr. No.        State    District Policestation  Year  FIR_No.
# 0        1  MAHARASHTRA  THANE CITY     AMBERNATH  2023       75  \
# 1        2  MAHARASHTRA  THANE CITY     AMBERNATH  2023       74
# 2        3  MAHARASHTRA  THANE CITY     AMBERNATH  2023       73
# 3        4  MAHARASHTRA  THANE CITY     AMBERNATH  2023       72
# 4        5  MAHARASHTRA  THANE CITY     AMBERNATH  2023       71
#
#   Registration_Date                                            Section
# 0  01-02-2023 12:09        Indian Electricity Act (Reform) 2003 - 135;
# 1  01-02-2023 11:58        Indian Electricity Act (Reform) 2003 - 135;
# 2  01-02-2023 02:59                       Indian Penal Code 180 - 373;
# 3  31-01-2023 21:31  Indian Penal Code 180 - 249, 337,337; Motor Ve...
# 4  31-01-2023 19:43          Maharashtra Darubandi Act, 1979 - 65 (E);

# %%
data.tail(5)
# Out:
#       Sr. No.        State    District Policestation  Year  FIR_No.
# 1591     1592  MAHARASHTRA  THANE CITY  WAGLE ESTATE  2023        5  \
# 1592     1593  MAHARASHTRA  THANE CITY  WAGLE ESTATE  2023        4
# 1593     1594  MAHARASHTRA  THANE CITY  WAGLE ESTATE  2023        3
# 1594     1595  MAHARASHTRA  THANE CITY  WAGLE ESTATE  2023        2
# 1595     1596  MAHARASHTRA  THANE CITY  WAGLE ESTATE  2023        1
#
#      Registration_Date                                  Section
# 1591  08-01-2023 12:10  Indian Penal Code 180 - 323,326,34,507;
# 1592  06-01-2023 17:11             Indian Penal Code 180 - 379;
# 1593  03-01-2023 18:27      Maharashtra Police Act, 1951 - 142;
# 1594  02-01-2023 15:10          Indian Penal Code 180 - 37,620;
# 1595  02-01-2023 02:14      Maharashtra Police Act, 1951 - 142;

# %%
data.shape
# Out:
# (1596, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1596 entries, 0 to 1595
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr. No.            1596 non-null   int64
#  1   State              1596 non-null   object
#  2   District           1596 non-null   object
#  3   Policestation      1596 non-null   object
#  4   Year               1596 non-null   int64
#  5   FIR_No.            1596 non-null   int64
#  6   Registration_Date  1596 non-null   object
#  7   Section            1596 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 99.9+ KB

# %%
data[data["Section"]=="Indian Penal Code 180 - 373;"]
# Out:
#       Sr. No.        State    District Policestation  Year  FIR_No.
# 2           3  MAHARASHTRA  THANE CITY     AMBERNATH  2023       73  \
# 30         31  MAHARASHTRA  THANE CITY     AMBERNATH  2023       45
# 68         69  MAHARASHTRA  THANE CITY     AMBERNATH  2023        4
# 77         78  MAHARASHTRA  THANE CITY      BADLAPUR  2023       33
# 87         88  MAHARASHTRA  THANE CITY      BADLAPUR  2023       23
# ...       ...          ...         ...           ...   ...      ...
# 1549     1550  MAHARASHTRA  THANE CITY   VITTHALWADI  2023       29
# 1563     1564  MAHARASHTRA  THANE CITY   VITTHALWADI  2023       14
# 1568     1569  MAHARASHTRA  THANE CITY   VITTHALWADI  2023        9
# 1588     1589  MAHARASHTRA  THANE CITY  WAGLE ESTATE  2023        8
# 1590     1591  MAHARASHTRA  THANE CITY  WAGLE ESTATE  2023        6
#
#      Registration_Date                       Section
# 2     01-02-2023 02:59  Indian Penal Code 180 - 373;
# ...

# %%
data.describe()
# Out:
#           Sr. No.    Year      FIR_No.
# count  1596.00000  1596.0  1596.000000
# mean    798.50000  2023.0    32.383459
# std     460.86983     0.0    25.224724
# min       1.00000  2023.0     1.000000
# 25%     399.75000  2023.0    13.000000
# 50%     798.50000  2023.0    26.000000
# 75%    1197.25000  2023.0    46.000000
# max    1596.00000  2023.0   115.000000

# %%
data.Policestation.unique()
# Out:
# array(['AMBERNATH', 'BADLAPUR', 'BADLAPUR WEST', 'BAZARPETH',
#        'BHIWANDI CITY', 'BHOIWADA', 'CENTRAL',
#        'CHITALSAR MANPADA POLICE STATION', 'DAIGHAR',
#        'DOMBIVALI POLICE STATION', 'HILL LINE', 'KALWA', 'KAPURBAWDI',
#        'KASARWADAWALI', 'KHADAKPADA POLICE STATION', 'KOLSEWADI', 'KON',
#        'KOPARI', 'MAHATMA PHULE CHOWK', 'MANPADA', 'MUMBRA', 'NARPOLI',
#        'NAUPADA', 'NIJAMPURA', 'RABODI', 'SHANTI NAGAR', 'SHIVAJINAGAR',
#        'SHRINAGAR', 'THANE TOWN', 'TILAK NAGAR (DOMBIVALI)', 'ULHASNAGAR',
#        'VARTAK NAGAR', 'VISHNU NAGAR', 'VITTHALWADI', 'WAGLE ESTATE'],
#       dtype=object)

# %%
data.Section.unique()
# Out:
# array(['Indian Electricity Act (Reform) 2003 - 135;',
#        'Indian Penal Code 180 - 373;',
#        'Indian Penal Code 180 - 249, 337,337; Motor Vehicle Act, 1979 - 134 (a), 134 (b), 184;',
#        'Maharashtra Darubandi Act, 1979 - 65 (E);',
#        'Indian Penal Code 180 - 243;',
#        'Indian Penal Code 180 - 323,326,507,507;',
#        'Indian Penal Code 180 - 307,326,506 (2);',
#        'Indian Penal Code 180 - 379;',
#        'Maharashtra Police Act, 1951 - 135,142,37 (1);',
#        'Maharashtra Police Act, 1951 - 142;',
#        'Maharashtra Jugar Restrictive Act, 14 - 12 (a);',
#        'Indian Penal Code 180 - 324,37,506 (2);',
#        'Indian Penal Code 180 - 183,16,149, 337,626;',
#        'Indian Penal Code 180 - 324,626,652;',
#        'Indian Penal Code 180 - 370,656;',
#        'The women and muli immoral trade (restrictions) Act, 1956 (Situ Act Restored) - 4,5; Indian Penal Code 180 - 37,360 (2), 370 (3);',
# ...

# %%
data[data["Policestation"]=='KOPARI']
# Out:
#      Sr. No.        State    District Policestation  Year  FIR_No.
# 727      728  MAHARASHTRA  THANE CITY        KOPARI  2023       16  \
# 728      729  MAHARASHTRA  THANE CITY        KOPARI  2023       15
# 729      730  MAHARASHTRA  THANE CITY        KOPARI  2023       14
# 730      731  MAHARASHTRA  THANE CITY        KOPARI  2023       13
# 731      732  MAHARASHTRA  THANE CITY        KOPARI  2023       12
# 732      733  MAHARASHTRA  THANE CITY        KOPARI  2023       11
# 733      734  MAHARASHTRA  THANE CITY        KOPARI  2023       10
# 734      735  MAHARASHTRA  THANE CITY        KOPARI  2023        9
# 735      736  MAHARASHTRA  THANE CITY        KOPARI  2023        8
# 736      737  MAHARASHTRA  THANE CITY        KOPARI  2023        7
# 737      738  MAHARASHTRA  THANE CITY        KOPARI  2023        6
# 738      739  MAHARASHTRA  THANE CITY        KOPARI  2023        5
# 739      740  MAHARASHTRA  THANE CITY        KOPARI  2023        4
# ...

# %%
data.isnull().sum()
# Out:
# Sr. No.              0
# State                0
# District             0
# Policestation        0
# Year                 0
# FIR_No.              0
# Registration_Date    0
# Section              0
# dtype: int64

# %%
outlets = data["Section"].value_counts()

# %%
outlets
# Out:
# Section
# Indian Penal Code 180 - 379;                                                                                                                                                                                                                                                                215
# Indian Penal Code 180 - 243;                                                                                                                                                                                                                                                                196
# Indian Penal Code 180 - 373;                                                                                                                                                                                                                                                                113
# ...

# %%
plt.figure(figsize=(5,5))
plt.bar(list(data["Section"].value_counts()[0:5].keys()),list(data["Section"].value_counts()[0:5]),color=["blue","green","red","pink","orange"])
plt.show()

# %%
data["Policestation"].nunique()
# Out:
# 35

# %%
plt.figure(figsize=(7,7))
plt.pie(list(data["Policestation"].value_counts()),labels=list(data["Policestation"].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
data.shape
# Out:
# (1596, 8)

# %%
from numpy import single
print("Total Section = ", data.shape[0])
print("Total FIR_No. = ", data.shape[0])
# Out:
# Total Section =  1596
# Total FIR_No. =  1596

# %%
outlets = data["Registration_Date"].value_counts()

# %%
outlets
# Out:
# Registration_Date
# 01-02-2023 16:12    3
# 04-01-2023 19:17    3
# 07-01-2023 14:59    2
# 29-01-2023 18:19    2
# 13-01-2023 17:14    2
#                    ..
# 27-01-2023 03:03    1
# 28-01-2023 00:23    1
# 28-01-2023 02:51    1
# 28-01-2023 14:39    1
# 02-01-2023 02:14    1
# Name: count, Length: 1568, dtype: int64

# %%
outlets.duplicated
# Out:
# <bound method Series.duplicated of Registration_Date
# 01-02-2023 16:12    3
# 04-01-2023 19:17    3
# 07-01-2023 14:59    2
# 29-01-2023 18:19    2
# 13-01-2023 17:14    2
#                    ..
# 27-01-2023 03:03    1
# 28-01-2023 00:23    1
# 28-01-2023 02:51    1
# 28-01-2023 14:39    1
# 02-01-2023 02:14    1
# Name: count, Length: 1568, dtype: int64>

# %%
outlets.shape
# Out:
# (1568,)

# %%
sns.kdeplot(data['FIR_No.'], shade=True)
plt.title("Policestation")
plt.show()
# Out:
# C:\Users\GAURAV\AppData\Local\Temp\ipykernel_2308\318719249.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['FIR_No.'], shade=True)

# %%
sns.kdeplot(data['FIR_No.'], shade=True)
plt.title("Section")
plt.show()
# Out:
# C:\Users\GAURAV\AppData\Local\Temp\ipykernel_2308\1616205422.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['FIR_No.'], shade=True)

# %%
data.to_csv("Database1.csv")

# %% [markdown]
# Conclusions
# After working on this data, we can conclude the following things:-
# Here are some observations and conclusions that can be drawn:
#
# The data includes sections from the Indian Penal Code (IPC) as well as the Indian Electricity Act (Reform) 2003 and the Motor Vehicle Act, 1979.
#
# The table provides a list of different sections, such as IPC 180-379, 180-243, 180-373, 180-370, 656, 656, 180-249, 304-A, 624, and others.
#
# The count column indicates the frequency of occurrence of each section, suggesting how many times a particular section has been mentioned in the dataset.
#
# The year column specifies that the data is related to the year 2023.
#
# The FIR_No. column represents the First Information Report numbers associated with the respective sections.
#
# The mean value of the FIR_No. column is approximately 32.38, indicating an average number of FIRs per section.
#
# The standard deviation (std) of 25.22 suggests a considerable variation in the number of FIRs across different sections.
#
# The minimum and maximum FIR numbers are 1 and 115, respectively, indicating the range of FIRs recorded.
#
# The quartiles (25%, 50%, and 75%) of the FIR_No. column provide insights into the distribution of FIR numbers, suggesting the middle values and the range between them.
#
# From this information, it is difficult to draw any specific conclusions about the nature of the data or its significance without further context. It appears to be a collection of FIR numbers related to different sections of Indian laws, but the purpose or context of this data is unclear. Additional information would be needed to provide a more detailed analysis or draw specific conclusions from this report.
# Now we have come to the end of this project, I hope you learned some new tricks.
